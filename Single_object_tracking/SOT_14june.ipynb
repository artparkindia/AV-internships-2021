# %%
import numpy as np
import pandas as pd
import os
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Importing data from output file of data extracter

# %%
measurements = np.load('Dataset_Extractor\\2_bicyclist_data.npz', allow_pickle=True)['arr_0']

# %% [markdown]
# # Cluster Plotter
#
# ## 1.Downsampling and clustering data
#
#
#
# ## 2.Mean of clusters
# 1. Creating dataframe to store mean of each Cluster
# 2. Ploting mean and x,y axis
#
# # visualization of Lidar Data

# %%
def Cluster_plotter(k):
        
        Xsamp = measurements[k] #measurement[i] i is the data from 1 textfile
        sampling = 10
        total_num_of_points=100000


        #downsampling to only 12k points out of 120k
        Xthres=[]
        for j in range(0,total_num_of_points, sampling):
                Xthres.append(Xsamp[j])
        X = pd.DataFrame(Xthres)

        #removing ground and clipping xy plane 20X20
        X = X.loc[(X[2]>-1)&(X[0]<20)&(X[0]>-20)&(X[1]<20)&(X[1]>-20)]


        #clustering trimmed data
        db = DBSCAN(eps=0.7, min_samples=15).fit(X)
        core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        core_samples_mask[db.core_sample_indices_] = True
        labels = db.labels_


        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise_ = list(labels).count(-1)

        #Assigning index to clusters
        X[4] = labels
        X = X.to_numpy()

        

        #Mean of a cluster
        X = pd.DataFrame(X)
        Xmean=[]
        for j in range(-1,n_clusters_):
                Y=X.loc[(X[4]==j)].mean()
                Xmean.append(Y)
                plt.scatter(Y[0],Y[1],label="Cluster : {}".format(j+1))
        Xmean=pd.DataFrame(Xmean)
        Xmean.columns=['X Coordinate','Y coordinate','Z coordinate','Reflectance','Cluster Label']
        print(Xmean)


        plt.axvline(x=0, c="green", label="x=0")
        plt.axhline(y=0, c="orange", label="y=0")

        # Set the limits of the plot
        plt.xlim(-20, 20)
        plt.ylim(-20, 20)

        # Don't mess with the limits!
        plt.autoscale(False)

        # Put a legend to the right of the current axis
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.show()


def plot(a, b):

        Xsamp = measurements[b] #measurement[i] i is the data from 1 textfile
        sampling = 10
        total_num_of_points=100000


        #downsampling to only 12k points out of 120k
        Xthres=[]
        for j in range(0,total_num_of_points, sampling):
                Xthres.append(Xsamp[j])
        X = pd.DataFrame(Xthres)

        #removing ground and clipping xy plane 20X20
        X = X.loc[(X[2]>-1)&(X[0]<20)&(X[0]>-20)&(X[1]<20)&(X[1]>-20)]
        db = DBSCAN(eps=0.7, min_samples=15).fit(X)
        core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        core_samples_mask[db.core_sample_indices_] = True
        labels = db.labels_


        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise_ = list(labels).count(-1)


        #Assigning index to clusters
        X[4] = labels
        X = X.to_numpy()


        #ploting clusters in xy plane
        if (a == 'xy'):
      
                # %matplotlib inline

                unique_labels = set(labels)
                unique_labels.remove(-1)
                print(unique_labels)
                colors = [plt.cm.Spectral(each)
                                for each in np.linspace(0, 1, len(unique_labels))]
                for k, col in zip(unique_labels, colors):
                                if k == -1:
                                        col = [0, 0, 0, 1]

                                class_member_mask = (labels == k)

                                xy = X[class_member_mask & core_samples_mask]
                                plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                                                 markeredgecolor=tuple(col), markersize=1)

                                xy = X[class_member_mask & ~core_samples_mask]
                                plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                                                markeredgecolor=tuple(col), markersize=1)

                plt.title('Estimated number of clusters: %d' % n_clusters_)

                plt.axvline(x=0, c="green", label="x=0")
                plt.axhline(y=0, c="orange", label="y=0")

                # Set the limits of the plot
                plt.xlim(-20, 20)
                plt.ylim(-20, 20)

                # Don't mess with the limits!
                plt.autoscale(False)

              

        #ploting clusters in yz plane  
        if (a == 'yz'):
        
                # %matplotlib inline
        
                unique_labels = set(labels)
                unique_labels.remove(-1)
                print(unique_labels)
                colors = [plt.cm.Spectral(each)
                                for each in np.linspace(0, 1, len(unique_labels))]
                for k, col in zip(unique_labels, colors):
                                if k == -1:
                                        col = [0, 0, 0, 1]

                                class_member_mask = (labels == k)

                                xy = X[class_member_mask & core_samples_mask]
                                plt.plot(xy[:, 1], xy[:, 2], 'o', markerfacecolor=tuple(col),
                                                markeredgecolor=tuple(col), markersize=1)

                                xy = X[class_member_mask & ~core_samples_mask]
                                plt.plot(xy[:, 1], xy[:, 2], 'o', markerfacecolor=tuple(col),
                                                markeredgecolor=tuple(col), markersize=1)

                plt.title('Estimated number of clusters: %d' % n_clusters_)

                plt.axvline(x=0, c="green", label="x=0")
                plt.axhline(y=0, c="orange", label="y=0")

                # Set the limits of the plot
                plt.xlim(-20, 20)
                plt.ylim(-1, 3)

                # Don't mess with the limits!
                plt.autoscale(False)

          

        #ploting clusters in xz plane
        if (a == 'xz'):
       
                # %matplotlib inline

                unique_labels = set(labels)
                unique_labels.remove(-1)
                print(unique_labels)
                colors = [plt.cm.Spectral(each)
                                for each in np.linspace(0, 1, len(unique_labels))]
                for k, col in zip(unique_labels, colors):
                                if k == -1:
                                        col = [0, 0, 0, 1]

                                class_member_mask = (labels == k)

                                xy = X[class_member_mask & core_samples_mask]
                                plt.plot(xy[:, 0], xy[:, 2], 'o', markerfacecolor=tuple(col),
                                                 markeredgecolor=tuple(col), markersize=1)

                                xy = X[class_member_mask & ~core_samples_mask]
                                plt.plot(xy[:, 0], xy[:, 2], 'o', markerfacecolor=tuple(col),
                                                 markeredgecolor=tuple(col), markersize=1)

                plt.title('Estimated number of clusters: %d' % n_clusters_)

                plt.axvline(x=0, c="green", label="x=0")
                plt.axhline(y=0, c="orange", label="y=0")

                # Set the limits of the plot
                plt.xlim(-20, 20)
                plt.ylim(-1, 3)

                # Don't mess with the limits!
                plt.autoscale(False)

# %% [markdown]
# # Calling Cluster Plotter
# 1. Mean of clusters
# 2. XY View of clusters
# 3. YZ View of clusters
# 4. XZ View of clusters

# %%
for i in range(measurements.shape[0]):
    
    Fig=matplotlib.pyplot.gcf()

    Cluster_plotter(i)  
    #plot('xy', i)
    #plot('yz', i)
    #plot('xz', i)

    Fig.set_size_inches(19,11)

    Fig.savefig('Cluster_plotter_outputs\\2_bicyclist\\2_bicyclist_mean\\Mean' + str(i) + '.png', dpi=100)
    #Fig.savefig('Cluster_plotter_outputs\\2_bicyclist\\2_bicyclist_xy\\xy' + str(i) + '.png', dpi=100)
    #Fig.savefig('Cluster_plotter_outputs\\2_bicyclist\\2_bicyclist_yz\\yz' + str(i) + '.png', dpi=100)
    #Fig.savefig('Cluster_plotter_outputs\\2_bicyclist\\2_bicyclist_xz\\xz' + str(i) + '.png', dpi=100)
